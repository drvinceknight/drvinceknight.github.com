# %%
import pathlib
import yaml


here = pathlib.Path("./")


for file in here.glob("*.md"):
    contents = file.read_text()
    contents = contents.replace("layout: default", "layout: publication")
    
    with open(f"{file.stem}.md", "w") as f:

        f.write(contents)

# %%
for author in authors:
    print(author, author.title().replace("-", " "))
# Out:
# steve-dumont Steve Dumont
# jon-gillard Jon Gillard
# adam-edwards Adam Edwards
# paul-slavin Paul Slavin
# alex-carney Alex Carney
# alex-anstey Alex Anstey
# tomáš-ehrlich Tomáš Ehrlich
# timothy-standen Timothy Standen
# cheryl-voake Cheryl Voake
# holly-tibble Holly Tibble
# rob-procter Rob Procter
# luke-sloan Luke Sloan
# martin-chorley Martin Chorley
# karl-molden. Karl Molden.
# noel-ann-bradshaw Noel Ann Bradshaw
# daniel-gartner Daniel Gartner
# aryono-djuned-pusponegoro Aryono Djuned Pusponegoro
# jeff-griffiths Jeff Griffiths
# andreas-artemiou Andreas Artemiou
# cathy-brooks Cathy Brooks
# thomas-campbell Thomas Campbell
# alex-voss Alex Voss
# syaribah-noor-brice Syaribah Noor Brice
# james-campbell James Campbell
# israel-vieira Israel Vieira
# jack-parry-jones Jack Parry Jones
# louise-orpin Louise Orpin
# robert-bares Robert Bares
# james-williams James Williams
# justin-boutilier Justin Boutilier
# jennifer-morgan Jennifer Morgan
# rob-wilson Rob Wilson
# ...
